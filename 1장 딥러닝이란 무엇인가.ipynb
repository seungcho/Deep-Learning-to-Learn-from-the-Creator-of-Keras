# %% [markdown]
# ## **CHPATER 1 딥러닝이란 무엇인가?**

# %% [markdown]
# ### **머신러닝에 대한 간략한 이해**

# %% [markdown]
# ![test](./img/머신러닝1.png)

# %% [markdown]
# ![test](./img/머신러닝2.jpg)

# %% [markdown]
# ![test](./img/머신러닝3.jpg)

# %% [markdown]
# ### **활용분야**

# %% [markdown]
# ![test](./img/대기.jpg)

# %% [markdown]
# ![test](./img/무역.jpg)

# %% [markdown]
# ![test](./img/활용.png)

# %% [markdown]
# ## **1.1 인공 지능과 머신 러닝, 딥러닝**

# %% [markdown]
# ![test](./img/AI.png)

# %% [markdown]
# ### 1.1.1 인공 지능

# %% [markdown]
# - 인공지능 분야에 대한 간결한 정의: 보통의 사람들이 수행하는 지능적인 작업을 자동화하기위한 연구 활동

# %% [markdown]
# - 이처럼 AI는 머신 러닝과 딥러닝을 포괄하는 종합적인 분야이다.

# %% [markdown]
# ### 1.1.2 머신 러닝

# %% [markdown]
# - **머신 러닝은 이런 질문에서부터 시작된다. "우리가 어떤 것을 작동시키기 위해 '어떻게 명령할지 알고 있는 것' 이상을 컴퓨터가 처리하는 것이 가능한가? 그리고 특정 작업을 수행하는 법을 스스로 학습할 수 있는가? 컴퓨터가 우리를 놀라게 할 수 있을까? 프로그래머가 직접 만든 데이터 처리 규칙 대신 컴퓨터가 데이터를 보고 자동으로 이런 규칙을 학습할 수 있을까?"**

# %% [markdown]
# ![test](./img/패러다임.png)

# %% [markdown]
# - 전통적인 프로그래밍인 심볼릭 AI의 패러다임에서는 규칙과 이 규칙에 따라 처리될 데이터를 입력하면 해답을 출력

# %% [markdown]
# - **머신 러닝에서는 데이터와 이 데이터로부터 기대되는 해답을 입력하면 규칙이 출력**

# %% [markdown]
# - **머신 러닝 시스템은 명시적으로 프로그램되는 것이 아니라 훈련(training)된다.**
# > - 작업과 관련 있는 많은 샘플을 제공하면 이 데이터에서 통계적 구조를 찾아 그 작업을 자동화하기 위한 규칙을 만들어 낸다.

# %% [markdown]
# - **머신 러닝은 수리 통계와 밀접하게 관련되어 있지만 통계와 다른 점이 몇 가지 있다.**
#   > - 머신 러닝은 통계와 달리 보통 대량의 복잡한 데이터셋을 다루기 때문에 베이지안 분석 같은 전통적인 통계 분석 방법은 현실적으로 적용하기 힘들다.
#
#   > - 따라서 머신 러닝, 특히 딥러닝은 수학적 이론이 비교적 부족하고 엔지니어링 지향적이다. 따라서 이론보다는 경험을 바탕으로 아이디어가 증명되는 경우가 많다.(즉, 이론적 배경이 부족)

# %% [markdown]
# ### 1.1.3 데이터에서 표현을 학습하기

# %% [markdown]
# - **머신 러닝을 하기 위해서는 세 가지가 필요**
#   > - 1) 입력 데이터 포인트
#
#   > - 2) 기대 출력(=label)
#
#   > - 3) 알고리즘의 성능을 측정하는 방법: 알고리즘의 현재 출력과 기대 출력 간의 차이를 결정

# %% [markdown]
# - **머신 러닝 모델은 입력 데이터를 의미 있는 출력으로 변환한다.**
#
#   > - 즉, 입력 데이터를 기반으로 기대 출력에 가깝게 만드는 유용한 표현을 학습시킨다.
#
#   >> - 여기서 표현이란 데이터를 인코딩 하거나 묘사하기 위해 데이터를 바라보는 다른 방법이다.
#
#   >> - 예를 들어 컬러 이미지는 RGB포맷(빨-녹-파)이나 HSV포맷(색상-채도-명도)로 인코딩될 수 있다. 이들은 같은 데이터의 두 가지 다른 표현이다.
#
#   >> - 어떤 표현으로는 해결하기 힘든 문제가 다른 표현으로는 쉽게 해결될 수 있다.
#
#   >> - 이미지에 있는 모든 빨간색 픽셀은 (RGB) , 이미지의 채도를 낮추는 것은 (HSV)포맷이 더 쉽다.

# %% [markdown]
# - 모든 머신 러닝 알고리즘은 주어진 작업을 위해 데이터를 더 유용한 표현으로 바꾸는 이런 변환을 자동으로 찾는다.
#
# > - 이러한 연산은 좌표변환, 선형 투영, 이동, 비선형 연산 등이 될 수 있다.

# %% [markdown]
# - **기술적으로 말하면 머신 러닝은 가능성 있는 공간을 사전에 정의하고 피드백 신호의 도움을 받아 입력 데이터에 대한 유용한 변환을 찾는 것이다.**

# %% [markdown]
# ### 1.1.4 딥러닝에서 '딥'이란 무엇일까?

# %% [markdown]
# - **딥러닝은 머신 러닝의 특정한 한 분야로서 연속된 층(layer)에서 점진적으로 의미 있는 표현을 배우는 데 강점이 있으며, 데이터로부터 표현을 학습하는 새로운 방식이다.**

# %% [markdown]
# - 딥러닝의 딥은 어떤 깊은 통찰이 아닌 그냥 연속된 층으로 표현을 학습한다는 개념을 나타낸다.
#
#   > - 이 분야에 대한 적절한 다른 이름은 **층 기반 표현 학습** 또는 **계층적 표현 학습**이다.
#
# - 최근의 딥러닝 모델은 표현 학습을 위해 수십 개, 수백 개의 연속된 층을 가지고 이 층들을 모두 훈련 데이터에 노출해서 자동으로 학습 시킨다.
#
#   > - 머신러닝은 1 ~ 2개의 데이터 표현 층을 학습하는 경향이 있다. 이런 방식을 **얕은 학습**

# %% [markdown]
# - **딥러닝에서는 기본 층을 겹겹이 쌓아 올려 구성한 신경망(neural network)이라는 모델을 사용하여 표현 층을 학습한다.**
#
#   > - 딥러닝 모델이 뇌를 모델링한 근거는 전혀 없다.
#
#   > - 우리가 다루는 딥러닝은 그냥 데이터로부터 표현을 학습하는 수학 모델일 뿐이다.

# %% [markdown]
# ![test](./img/심층신경망1.png)

# %% [markdown]
# -  **위 그림에서 볼 수 있듯이 최종 출력에 대해 점점 더 많은 정보를 가지지만 원본 이미지와는 다르게 층을 거치면서 점점 더 다른 표현으로 숫자 이미지가 변환된다.**

# %% [markdown]
# - 심층 신경망을 정보가 연속된 필터(filter)를 통과하면서 순도 높게(즉, 어떤 작업에 대해서 유용하게) 정제되는 다단계 정보 추출 작업으로 생각 할 수 있다.

# %% [markdown]
# ![test](./img/이미지.jpg)

# %% [markdown]
# ### 1.1.5 그림으로 딥러닝의 작동 원리 이해하기

# %% [markdown]
# - 층에서 입력 데이터가 처리되는 상세 내용은 입력의 숫자로 이루어진 층의 가중치(Weight)에 저장되어 있다.
#
#   > - **즉 어떤 층에서 일어나는 변환은 그 층의 가중치를 파라미터로 가지는 함수로 표현된다.**
#
#   > - **이러한 맥란으로 학습은 주어진 입력을 정확한 타깃에 매핑하기 위해 신경망의 모든 층에 있는 가중치 값을 찾는 것을 의미한다.**

# %% [markdown]
# - 수천만 개의 파라미터의 정확한 값을 찾는 것은 어려운 일이다.
#
#   > - 하나의 가중치를 변경하면 전체의 가중치에 영향을 주기 때문
#
# - **신경망의 출력을 제어하려면 출력이 기대하는 것보다 얼마나 벗어났는지를 측정해야 한다. 이는 신경망의 손실 함수 또는 목적 함수가 담당하는 일이다.**

# %% [markdown]
# - **신경망이 한 샘플에 대해 얼마나 잘 예측했는지 측정하기 위해 손실 함수가 신경망의 예측과 진짜 타깃의 차이를 점수로 계산한다.**

# %% [markdown]
# ![test](./img/신경망.png)

# %% [markdown]
# - 위 그림에서 clssification(분류)작업이 끝나면 우리가 예측한 타깃값과 실제 값(label)에 대한 차이를 손실함수를 거쳐 손실 점수를 반환한다.

# %% [markdown]
# - **이 손실 점수를 피드백 신호를 사용하여 현재 샘플의 손실 점수가 감소되는 방향으로 가중치 값을 조금씩 수정하는 것이다.**
# > - 이런 수정 과정은 딥러닝의 핵심 알고리즘인 **역전파(backppropagation)알고리즘**으로 구현한 옵티마이저(optimizer)가 담당한다.

# %% [markdown]
# - **요악하면, 초기에는 가중치가 랜덤한 값으로 할당되어 손실 점수가 매우 높지만 네트워크가 모든 샘플을 처리하면서 가중치가 조금씩 올바른 방향으로 조정되고 손실 점수가 감소한다. 이런 최소한의 손실을 내는 네트워크가 타깃에 가능한 가장 가까운 출력을 만드는 모델이 된다.**

# %% [markdown]
# ## **1.2 딥러닝 이전: 머신러닝의 간략한 역사**

# %% [markdown]
# - 오늘날 산업계에서 사용하는 대부분의 머신러닝 알고리즘은 딥러닝 알고리즘이 아니다. 또한, 딥러닝이 모든 작업에 맞는 만능 도구도 아니다.

# %% [markdown]
# - 이러한 함정에 빠지지 않기 위한 유일한 방법은 다른 방법들을 배우고 가능할 때 이런 기술을 연습하는 것이다.

# %% [markdown]
# ### 1.2.1 확률적 모델링

# %% [markdown]
# - 확률적 모델링은 통계학 이론을 데이터 분석에 응용한 것이다.

# %% [markdown]
# - 가장 잘 알려진 알고리즘 중 하나는 나이브 베이즈 알고리즘이다.
# > - 나이브 베이즈는 입력 데이터의 특성이 모두 독립적이라고 가정하고 베이즈 정리를 적용하는 머신 러닝 분류 알고리즘이다.
#
# - 로지스틱 회귀
#
# > - **분류를 위한 알고리즘으로 현대 머신 러닝의 'hello world'로 여겨진다.**
#
# > - 간단하고 다목적으로 활용할 수 있어서 오늘날에도 여전히 유용하다.

# %% [markdown]
# ### 1.2.2 초창기 신경망

# %% [markdown]
# - 신경망의 핵심 아이디어는 아주 일찍 1950년대에 작으나마 연구되었지만 대규모 신경망을 훈련시킬 수 있는 효과적인 방법을 오랜 기간동안 찾지 못했기 떄문에 본격적으로 시작되기까지는 수십 년이 걸렸다.

# %% [markdown]
# ### 1.2.3 커널방법

# %% [markdown]
# - 머신 러닝의 새로운 접근 방법인 커널 방법이 인기를 얻자 신경망은 빠르게 사라졌다.

# %% [markdown]
# - **커널 방법은 분류 알고리즘의 한 종류를 말하며  서포트 벡터 머신(Support vector machine)이 가장 유명하다.**
#
# > - SVM은 분류 문제를 해결하기 위해 2개의 다른 범주에 속한 데이터 포인트 그룹 사이에 좋은 결정경계를 찾는다.
#
# > - 여기서 결정경계는 훈련 데이터를 2개의 범주에 대응하는 영역으로 나누는 직선이나 표면으로 생각할 수 있다.
#
# > - 따라서 결정 경계가 어느 쪽에 속하는지를 확인하기만 하면 된다.

# %% [markdown]
# ![test](./img/SVM.jpg)

# %% [markdown]
# - SVM이 결정 경계를 찾는 과정
#
# > **1.)결정 경계가 하나의 초평면으로 표현될 수 있는 새로운 고차원 표현으로 데이터를 매핑한다.**
# >> - 위 그림과 같이 데이터가 2차원 데이터라면 초평면은 직선이 된다.
#
# > **2.)초평면과 각 클래스의 가장 가까운 데이터 포인트 사이의 거리가 최대가 되는 최선의 결정 경계(하나의 분할 초평면)를 찾는다. 이 단계를 마진 최대화라 부른다. 이렇게 함으로써 결정 경계가 훈련 데이터셋 이외의 새로운 샘플에 잘 일반화 되도록 도와준다.**

# %% [markdown]
# - **하지만 데이터를 고차원 표현으로 매핑하는 기법이 이론상으로는 좋아 보이지만 실제로는 컴퓨터로 구현하기 어려운 경우가 많다.**

# %% [markdown]
# - 따라서 **커널 기법**이 등장했다.
#
# > - 새롭게 표현된 공간에서 좋은 결정 초평면을 찾기 위해 새로운 공간에 대응하는 데이터포인트의 좌표를 실제로 구할 필요가 없다.
#
# > - 새로운 공간에서의 두 데이터 포인트 사이의 거리를 계산할 수만 있으면 된다. 이를 커널 함수를 사용하면 효과적으로 계산할 수 있다.
#
# > - 커널 함수는 원본 공간에 있는 두 데이터 포인트를 명시적으로 새로운 표현으로 변환하지 않고 타깃 표현 공간에 위치했을 때의 거리를 매핑해 주는 계산 가능한 연산이다.

# %% [markdown]
# - SVM은 머신러닝 초창기에 최고 수준의 성능을 달성했고 이론을 이해하고 설명하기가 쉬웠다. 하지만 SVM은 대용량 데이터셋에 확장되기 어렵고 이미지 분류 같은 지각에 관련된 문제에서 좋은 성능을 내지 못한다. SVM얕은 학습방법이기 때문에 수동으로 유용한 표현을 추출해야 하는데 (feature engineering) 이는 매우 어렵고 불안정하다.

# %% [markdown]
# ### 1.2.4 결정 트리, 랜덤 포레스트, 그래디언트 부스팅 머신

# %% [markdown]
# - **결정 트리는 플로차트 같은 구조를 가지며 입력 데이터 포인트를 분류하거나 주어진 입력에 대해 출력 값을 예측한다.**
#
# > - 2000년대부터 연구자들에게 크게 관심을 받았고 현재는 커널 방법보다 선호

# %% [markdown]
# ![test](./img/결정트리.png)

# %% [markdown]
# - 특히 **랜덤 포레스트** 알고리즘은 결정 트리 학습에 기초한 것으로 실전에서 유용하다.
#
# > - 서로 다른 트리를 많이 만들고 그 출력을 앙상블하는 방법을 사용한다.

# %% [markdown]
# - 캐글에서 2010년까지 랜덤 포레스트가 가장 선호하는 알고리즘이였다면 2014년에는 그래디언트 부스팅 머신이 그 뒤를 이어받았다.
#
# > - 랜덤포레스트와 아주 비슷하게 그래디언트 부스팅 머신은 약한 예측 모델인 결정 트리를 앙상블하는 것을 기반을 하는 머신러닝 기법이다.
#
# > - 이 알고리즘은 이전 모델에서 놓친 데이터 포인트를 보완하는 새로운 모델을 반복적으로 훈련함으로써 머신 러닝 모델을 향상하는 방법인 그래디언트 부스팅을 사용
#
# > - 이 알고리즘이 오늘날 지각에 관련되지 않은 데이터를 다루기 위한 알고리즘 중 최고는 아니지만 가장 뛰어나다.

# %% [markdown]
# ![test](./img/그래디언트부스팅.png)

# %% [markdown]
# ### 1.2.6 딥러닝의 특징

# %% [markdown]
# - **딥러닝이 이렇게 빠르게 확산된 주된 이유는 많은 문제에서 더 좋은 성능을 내고 있기 때문이다.**

# %% [markdown]
# - **딥러닝은 머신 러닝에서 가장 중요한 단계인 특성 공학을 완전히 자동화하기 때문에 문제를 더 해결하기 쉽게 만들어 준다.**

# %% [markdown]
# - **딥러닝을 사용하면 특성을 직접 찾는 대신 한 번에 모든 특성을 학습할 수 있다. 머신 러닝 작업 흐름을 매우 단순화 시켜주므로 고도의 다단계 작업 과정을 하나의 간단한 엔드-투-엔드 딥러닝 모델로 대체 할 수 있다.**

# %% [markdown]
# - **딥러닝이 데이터로부터 학습하는 방법에는 두 가지 중요한 특징이 있다.**
#
# > - 층을 거치면서 점진적으로 더 복잡한 표현이 만들어진다.
#
# > - 이런 점진적인 중간 표현이 공동으로 학습된다.

# %% [markdown]
# ### 1.2.7 머신 러닝의 최근 동향

# %% [markdown]
# - 요즘 머신 러닝 알고리즘과 도구의 동향에 대한 정보를 얻는 좋은 방법은 캐글의 머신 러닝 경연

# %% [markdown]
# - **2016,2017년 캐글에는 그래디언트 부스팅 머신과 딥러닝의 두 가지 접근 방법이 주류를 이룬다.**
#
# > - 구조적인 데이터인 경우 XGBoost, 이미지와 같은 지각데이터의 경우 딥러닝이 사용된다.

# %% [markdown]
# ### **추가: 1.2.8 머신러닝에 필요한 역량**
